# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.3

# %%
import sys
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
sys.path.insert(0, '../cocoapi/PythonAPI/')
# sys.path.insert(0, 'src/data/cocoapi/PythonAPI/')
from pycocotools.coco import COCO

# %%
os.getcwd()
# Out:
# '/home/jdlevy/Documents/UCSD/Senior/Quarter 2/DSC 180B/generative_inpainting/notebooks'

# %%
COCO?

# %%
coco = COCO('../instances_val2017.json')
# Out:
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!

# %%
def get_random_idx(arr):
    return np.random.choice(range(len(arr)))

# %%
ann_ids
# Out:
# [409385, 410610, 1384284, 1773181, 2206549]

# %%
img_ids = coco.getImgIds()
img_id = img_ids[get_random_idx(img_ids)]
fname = coco.loadImgs(img_id)[0]['file_name']

# %%
img = Image.open(f'../../Image_Captioning_Explainer/data/raw/coco_data/val2017/{fname}')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7FF323DDADC0>

# %%
ann = coco.loadAnns(ann_id)[0]
ann
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3d305b9bd5aa> in <module>
# ----> 1 ann = coco.loadAnns(ann_id)[0]
#       2 ann
#
# NameError: name 'ann_id' is not defined

# %%
# ann_ids = coco.getAnnIds(img_id)
# ann_id = ann_ids[get_random_idx(ann_ids)]

ann = coco.loadAnns(ann_id)[0]

mask = coco.annToMask(ann) * 255

im = Image.fromarray(mask)
im.save(f'mask_{img_id}_{ann_id}.png')
im
# Out:
# <PIL.Image.Image image mode=L size=500x375 at 0x7F84B1B16630>

# %%
img = Image.open(f'../../Image_Captioning_Explainer/data/raw/coco_data/val2017/{fname}')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F84B1A28438>

# %%
img.save(f'raw_{img_id}.png')

# %%
# im = im.convert('RGBA')
# img = img.convert('RGBA')

# %%
import cv2

# %%
# cv2.bitwise_and?

# %%
# plt.imshow(coco.annToMask(ann), cmap='gray')

# %%
# mask = coco.annToMask(ann) * 255

# im = Image.fromarray(mask)
# im.save(f'mask_{ann_id}_{img_id}.png')

# plt.savefig()
#(coco.annToMask(ann))

# %%
img_1 = cv2.imread(f'raw_{img_id}.png')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
mask_img = cv2.imread(f'mask_{img_id}_{ann_id}.png')

# %%
img_1_mask = cv2.add(img_1, mask_img)

# %%
im2 = Image.fromarray(img_1_mask)
im2.save(f'input_{img_id}.png')

# %%
img_id
# Out:
# 410712

# %%
coco.loadImgs(ids=[coco.getImgIds()[0]])
# Out:
# [{'license': 4,
#   'file_name': '000000397133.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2017/000000397133.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-14 17:02:52',
#   'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg',
#   'id': 397133}]

# %%
sys.path.insert(0, '../../')
